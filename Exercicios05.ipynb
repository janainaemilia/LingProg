# %% [markdown]
# 1 - Linha: Crie a classe Linha que tem dois atributos, coordenada1 e coordenada2.
# Cada coordenada é uma tupla que carrega duas coordenadas cartesianas (x,yg que
# denotam pontos do segmento de reta. Faça métodos que calculem o comprimento
# do segmento de reta e sua inclinação.

# %%
import math

class Linha:
    def __init__(self, coordenada1, coordenada2):
        self.coordenada1 = coordenada1
        self.coordenada2 = coordenada2
    
    def comprimento(self):
        v1 = math.pow((self.coordenada2[0] - self.coordenada1[0]), 2)
        v2 = math.pow((self.coordenada2[1] - self.coordenada1[1]), 2)
        return math.sqrt(v1 + v2)
    
    def inclinacao(self):
        v1 = self.coordenada2[1] - self.coordenada1[1]
        v2 = self.coordenada2[0] - self.coordenada1[0]
        return v1 / v2
    
l = Linha((1,1),(3,2))

print(f'Comprimento do Segmento: {l.comprimento()}')
print(f'Inclinação: {l.inclinacao()}')
# Out:
# Comprimento do Segmento: 2.23606797749979
# Inclinação: 0.5

# %% [markdown]
# 2 Figuras: Crie a seguinte hierarquia de classes de figuras geométricas.
# - a. A classe abstrata Figura deve ter o método abstrato area.
# - b. A classe concreta Circulo é subclasse de Figura.
# - c. A classe abstrata Poligono é subclasse de Figura e deve ter os
# atributos base e altura .
# - d. As classes concretas Triangulo, Losango, Retangulo e Quadrado são
# subclasses de Poligono. Tente criar mais uma generalização aqui olhando as fórmulas
# da área.
# - e. Os polígonos Retangulo e Quadrado devem implementar a interface
# Diagonal, que deve ter um método que calcula a diagonal.
# - f. Crie uma classe Geometria com uma lista de Figuras com pelo menos
# uma figura de cada e imprima suas áreas, perímetros e diagonais.

# %%
from abc import ABC, abstractmethod
import math
class Figura(ABC):

    def __init__(self):
        super().__init__()

    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimetro(self):
        pass

class Circulo(Figura):

    def __init__(self, raio):
        self.raio = raio
        Figura.__init__(self)

    def area(self):
        return math.pi * (self.raio**2)

    def perimetro(self):
        return 2 * math.pi * self.raio

    def diagonal(self):
        pass

    

class Poligono(Figura, ABC):

    def __init__(self, base, altura):
        self.base = base
        self.altura = altura
        Figura.__init__(self)

class Diagonal(ABC):

    def __init__(self):
        super().__init__()

    def diagonal(self):
        return math.sqrt((self.base**2) + (self.altura**2))

class Triangulo(Poligono):

    def __init__(self, base, altura):
        super().__init__(base, altura)

    def area(self):
        return (self.base * self.altura) / 2

    def perimetro(self):
        pass
    
    def diagonal(self):
        pass

class Losango(Poligono):

    def __init__(self, base, altura):
        Poligono.__init__(self, base, altura)

    def area(self):
        return (self.base * self.altura) / 2

    def perimetro(self):
        return self.base*2 + self.altura*2

    def diagonal(self):
        pass

class Retangulo(Poligono, Diagonal):

    def __init__(self, base, altura):
        Poligono.__init__(self, base, altura)
        Diagonal.__init__(self)

    def area(self):
        return self.base * self.altura

    def diagonal(self):
        return math.sqrt((self.base**2) + (self.altura**2))

    def perimetro(self):
        return self.base*2 + self.altura*2

class Quadrado(Poligono):

    def __init__(self, base, altura):
        super().__init__(base, altura)

    def area(self):
        return self.base * self.altura

    def perimetro(self):
        return self.base*2 + self.altura*2

    def diagonal(self):
        return math.sqrt((self.base**2) + (self.altura**2))

class Geometria:

    def __init__(self):
        self.figuras = [
            Circulo(15),
            Triangulo(7, 8),
            Quadrado(4, 8),
            Losango(6, 7),
            Retangulo(7, 7)
        ]

geometria = Geometria()
for figura in geometria.figuras:
    print("Área: ", figura.area())
    print("Diagonal", figura.diagonal())
    print("Perímetro: " + str(figura.perimetro()) + "\n")
# Out:
# Área:  706.8583470577034
# Diagonal None
# Perímetro: 94.24777960769379
#
# Área:  28.0
# Diagonal None
# Perímetro: None
#
# Área:  32
# Diagonal 8.94427190999916
# Perímetro: 24
#
# Área:  21.0
# Diagonal None
# Perímetro: 26
#
# Área:  49
# Diagonal 9.899494936611665
# Perímetro: 28
